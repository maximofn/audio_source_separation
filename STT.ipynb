# %%
import whisper

# %%
audio = "audio_sepformer-libri2mix_source_1.wav"
model = whisper.load_model("large-v3", device="cuda")
result = model.transcribe(audio, word_timestamps=True)

# %%
result.keys()
# Out:
# dict_keys(['text', 'segments', 'language'])

# %%
result["text"]
# Out:
# ' Мало людей, очень мало людей для такой музыки, очень мало. Очень много народу, да. А где? Очень, ой, ой. Эх, а что? Бесплатная музыка. На самом деле, очень плохая музыка. А ты где выгружение читаешь? Я думал, намного лучше будет это всё. И очень плохая музыка, просто очень плохая музыка. Я думал, намного лучше это всё будет. сколько раз туда ходил было намного лучше но и на этот раз как-то не удалось во-первых народа мама музыка не очень направление направление направление и'

# %%
result["language"]
# Out:
# 'ru'

# %%
result["segments"]
# Out:
# [{'id': 0,
#   'seek': 0,
#   'start': 0.0,
#   'end': 3.42,
#   'text': ' Мало людей, очень мало людей для такой музыки, очень мало.',
#   'tokens': [50365,
#    3493,
#    12441,
#    16810,
#    11,
#    6730,
#    37450,
#    16810,
#    5561,
#    13452,
#    34249,
#    2241,
#    11,
#    6730,
#    37450,
#    13,
#    50544],
#   'temperature': 0.6,
#   'avg_logprob': -0.5372926621210008,
#   'compression_ratio': 2.37603305785124,
#   'no_speech_prob': 0.06435810774564743,
#   'words': [{'word': ' Мало',
#     'start': 0.0,
#     'end': 0.46,
#     'probability': 0.6381307989358902},
#    {'word': ' людей,',
#     'start': 0.46,
#     'end': 0.76,
#     'probability': 0.9776670336723328},
#    {'word': ' очень',
#     'start': 0.86,
#     'end': 1.04,
#     'probability': 0.9826436638832092},
#    {'word': ' мало',
#     'start': 1.04,
#     'end': 1.28,
#     'probability': 0.9971297383308411},
#    {'word': ' людей',
#     'start': 1.28,
#     'end': 1.58,
# ...
